# %%
def get_bio_text(df):
    import re
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd

    ## Loop thorugh every senator to get bios
    for i in range(len(df)):
        ## Go to url of each senator
        url = 'http://bioguide.congress.gov/scripts/biodisplay.pl?index={}'.format(df.loc[i, 'bioguide_id'])
        r = requests.get(url)
        c = r.content
        soup = BeautifulSoup(c, "lxml")

        ## Save bio text in data set
        bio_text = str(soup.findAll('p')[0])
        df.loc[i, 'bio_text'] = re.sub("<[^>]*>","",bio_text).replace('\r','').replace('\n','')
    return df

def put_into_sql(data_set):
    import sqlite3
    import pandas as pd
    from sqlalchemy import create_engine

    engine = create_engine('sqlite:///rep_zone.db')
    connection = sqlite3.connect("rep_zone.db")

    cursor = connection.cursor()

    # delete 
    try:
        cursor.execute("""DROP TABLE current_rep_bio;""")
    except:
        'table did not exist'

    sql_command = """
    CREATE TABLE current_rep_bio (
    address varchar(255), 
    bioguide_id PRIMARY KEY, 
    class_ varchar(255), 
    email Hyperlink, 
    first_name varchar(255), 
    last_name varchar(255), 
    leadership_position varchar(255), 
    member_full varchar(255), 
    party varchar(255), 
    phone varchar(255), 
    state varchar(255), 
    website Hyperlink,
    bio_text LONGTEXT);"""

    cursor.execute(sql_command)

    for i in range(len(data_set)):
        x = list(data_set.loc[i,])

        for p in [x]:
            format_str = """INSERT INTO current_rep_bio (
            address, 
            bioguide_id, 
            class_, 
            email, 
            first_name, 
            last_name, 
            leadership_position, 
            member_full, 
            party, 
            phone, 
            state, 
            website,
            bio_text)
            VALUES ("{address}", "{bioguide_id}", "{class_}", "{email}", "{first_name}", "{last_name}", 
            "{leadership_position}", "{member_full}", "{party}", "{phone}", "{state}",
            "{website}", "{bio_text}");"""

            sql_command = format_str.format(address=p[0], bioguide_id=p[1], class_=p[2], email=p[3], first_name=p[4], last_name=p[5], 
                              leadership_position=p[6], member_full=p[7], party=p[8],phone=p[9], state=p[10],
                              website=p[11], bio_text=p[12])
            cursor.execute(sql_command)

    # never forget this, if you want the changes to be saved:
    connection.commit()

    connection.close()


def get_senator_info():
    
    import pandas as pd
    import requests
    from json import dumps
    from xmljson import badgerfish as bf
    from xml.etree.ElementTree import fromstring
    from pandas.io.json import json_normalize
    import sqlalchemy
    import sqlite3

    url = 'http://www.senate.gov/general/contact_information/senators_cfm.xml'
    r = requests.get(url)
    x = json_normalize(pd.DataFrame(bf.data(fromstring(r.content))).loc['member', 'contact_information'])
    x.columns = x.columns.str.replace('$', '').str.replace('.', '')
    
    ## Collect bios before I sent to sql db
    get_bio_text(x)
    
    ## Put into sql
    ## code below is depricated for now
    #x.to_sql('current_rep_bio', 'sqlite:///rep_zone.db', if_exists='replace', index=False, 
    #         index_label='bioguide_id', flavor='mysql')
    put_into_sql(x)

    print 'done!'

get_senator_info()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d9c26c40a4ff> in <module>()
#     112     print 'done!'
#     113
# --> 114 get_senator_info()
#
# <ipython-input-1-d9c26c40a4ff> in get_senator_info()
#      90     import requests
#      91     from json import dumps
# ---> 92     from xmljson import badgerfish as bf
#      93     from xml.etree.ElementTree import fromstring
#      94     from pandas.io.json import json_normalize
#
# ImportError: No module named xmljson

# %%
get_senator_info()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-787931ee3ef7> in <module>()
# ----> 1 get_senator_info()
#
# <ipython-input-1-d9c26c40a4ff> in get_senator_info()
#      90     import requests
#      91     from json import dumps
# ---> 92     from xmljson import badgerfish as bf
#      93     from xml.etree.ElementTree import fromstring
#      94     from pandas.io.json import json_normalize
#
# ImportError: No module named xmljson

# %%
import pandas as pd
import requests
from json import dumps
from xmljson import badgerfish as bf
from xml.etree.ElementTree import fromstring
from pandas.io.json import json_normalize
import sqlalchemy
import sqlite3

url = 'http://www.senate.gov/general/contact_information/senators_cfm.xml'
r = requests.get(url)
x = json_normalize(pd.DataFrame(bf.data(fromstring(r.content))).loc['member', 'contact_information'])
x.columns = x.columns.str.replace('$', '').str.replace('.', '')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-948e403e3b00> in <module>()
#       2 import requests
#       3 from json import dumps
# ----> 4 from xmljson import badgerfish as bf
#       5 from xml.etree.ElementTree import fromstring
#       6 from pandas.io.json import json_normalize
#
# ImportError: No module named xmljson

# %%
import pandas as pd
import requests
from json import dumps
from xml.etree.ElementTree import fromstring
from pandas.io.json import json_normalize
import sqlalchemy
import sqlite3

url = 'http://www.senate.gov/general/contact_information/senators_cfm.xml'
r = requests.get(url)

# %%
r.content
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><contact_information><member>\n        <member_full>Alexander (R-TN)</member_full>\n        <last_name>Alexander</last_name>\n        <first_name>Lamar</first_name>\n        <party>R</party>\n        <state>TN</state>\n        <address>455 Dirksen Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-4944</phone>\n        <email>http://www.alexander.senate.gov/public/index.cfm?p=Email</email>\n        <website>http://www.alexander.senate.gov/</website>\n        <class>Class II</class>\n        <bioguide_id>A000360</bioguide_id>\n    </member><member>\n        <member_full>Ayotte (R-NH)</member_full>\n        <last_name>Ayotte</last_name>\n        <first_name>Kelly</first_name>\n        <party>R</party>\n        <state>NH</state>\n        <address>144 Russell Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-3324</phone>\n        <email>https://www.ayotte.senate.gov/?p=contact</email>\n        <website>http://www.ayotte.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>A000368</bioguide_id>\n    </member><member>\n        <member_full>Baldwin (D-WI)</member_full>\n        <last_name>Baldwin</last_name>\n        <first_name>Tammy</first_name>\n        <party>D</party>\n        <state>WI</state>\n        <address>717 Hart Washington DC 20510</address>\n        <phone>(202) 224-5653</phone>\n        <email>https://www.baldwin.senate.gov/feedback</email>\n        <website>http://www.baldwin.senate.gov/</website>\n        <class>Class I</class>\n        <bioguide_id>B001230</bioguide_id>\n    </member><member>\n        <member_full>Barrasso (R-WY)</member_full>\n        <last_name>Barrasso</last_name>\n        <first_name>John</first_name>\n        <party>R</party>\n        <state>WY</state>\n        <address>307 Dirksen Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-6441</phone>\n        <email>https://www.barrasso.senate.gov/public/index.cfm/contact-form</email>\n        <website>http://www.barrasso.senate.gov</website>\n        <class>Class I</class>\n        <bioguide_id>B001261</bioguide_id>\n    </member><member>\n        <member_full>Bennet (D-CO)</member_full>\n        <last_name>Bennet</last_name>\n        <first_name>Michael F.</first_name>\n        <party>D</party>\n        <state>CO</state>\n        <address>261 Russell Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-5852</phone>\n        <email>https://www.bennet.senate.gov/?p=contact</email>\n        <website>http://www.bennet.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>B001267</bioguide_id>\n    </member><member>\n        <member_full>Blumenthal (D-CT)</member_full>\n        <last_name>Blumenthal</last_name>\n        <first_name>Richard</first_name>\n        <party>D</party>\n        <state>CT</state>\n        <address>706 Hart Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-2823</phone>\n        <email>https://www.blumenthal.senate.gov/contact/</email>\n        <website>http://www.blumenthal.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>B001277</bioguide_id>\n    </member><member>\n        <member_full>Blunt (R-MO)</member_full>\n        <last_name>Blunt</last_name>\n        <first_name>Roy</first_name>\n        <party>R</party>\n        <state>MO</state>\n        <address>260 Russell Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-5721</phone>\n        <email>https://www.blunt.senate.gov/public/index.cfm/contact-roy</email>\n        <website>http://www.blunt.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>B000575</bioguide_id>\n    </member><member>\n        <member_full>Booker (D-NJ)</member_full>\n        <last_name>Booker</last_name>\n        <first_name>Cory A.</first_name>\n        <party>D</party>\n        <state>NJ</state>\n    ...

# %%
r.content
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><contact_information><member>\n        <member_full>Alexander (R-TN)</member_full>\n        <last_name>Alexander</last_name>\n        <first_name>Lamar</first_name>\n        <party>R</party>\n        <state>TN</state>\n        <address>455 Dirksen Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-4944</phone>\n        <email>http://www.alexander.senate.gov/public/index.cfm?p=Email</email>\n        <website>http://www.alexander.senate.gov/</website>\n        <class>Class II</class>\n        <bioguide_id>A000360</bioguide_id>\n    </member><member>\n        <member_full>Ayotte (R-NH)</member_full>\n        <last_name>Ayotte</last_name>\n        <first_name>Kelly</first_name>\n        <party>R</party>\n        <state>NH</state>\n        <address>144 Russell Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-3324</phone>\n        <email>https://www.ayotte.senate.gov/?p=contact</email>\n        <website>http://www.ayotte.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>A000368</bioguide_id>\n    </member><member>\n        <member_full>Baldwin (D-WI)</member_full>\n        <last_name>Baldwin</last_name>\n        <first_name>Tammy</first_name>\n        <party>D</party>\n        <state>WI</state>\n        <address>717 Hart Washington DC 20510</address>\n        <phone>(202) 224-5653</phone>\n        <email>https://www.baldwin.senate.gov/feedback</email>\n        <website>http://www.baldwin.senate.gov/</website>\n        <class>Class I</class>\n        <bioguide_id>B001230</bioguide_id>\n    </member><member>\n        <member_full>Barrasso (R-WY)</member_full>\n        <last_name>Barrasso</last_name>\n        <first_name>John</first_name>\n        <party>R</party>\n        <state>WY</state>\n        <address>307 Dirksen Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-6441</phone>\n        <email>https://www.barrasso.senate.gov/public/index.cfm/contact-form</email>\n        <website>http://www.barrasso.senate.gov</website>\n        <class>Class I</class>\n        <bioguide_id>B001261</bioguide_id>\n    </member><member>\n        <member_full>Bennet (D-CO)</member_full>\n        <last_name>Bennet</last_name>\n        <first_name>Michael F.</first_name>\n        <party>D</party>\n        <state>CO</state>\n        <address>261 Russell Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-5852</phone>\n        <email>https://www.bennet.senate.gov/?p=contact</email>\n        <website>http://www.bennet.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>B001267</bioguide_id>\n    </member><member>\n        <member_full>Blumenthal (D-CT)</member_full>\n        <last_name>Blumenthal</last_name>\n        <first_name>Richard</first_name>\n        <party>D</party>\n        <state>CT</state>\n        <address>706 Hart Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-2823</phone>\n        <email>https://www.blumenthal.senate.gov/contact/</email>\n        <website>http://www.blumenthal.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>B001277</bioguide_id>\n    </member><member>\n        <member_full>Blunt (R-MO)</member_full>\n        <last_name>Blunt</last_name>\n        <first_name>Roy</first_name>\n        <party>R</party>\n        <state>MO</state>\n        <address>260 Russell Senate Office Building Washington DC 20510</address>\n        <phone>(202) 224-5721</phone>\n        <email>https://www.blunt.senate.gov/public/index.cfm/contact-roy</email>\n        <website>http://www.blunt.senate.gov</website>\n        <class>Class III</class>\n        <bioguide_id>B000575</bioguide_id>\n    </member><member>\n        <member_full>Booker (D-NJ)</member_full>\n        <last_name>Booker</last_name>\n        <first_name>Cory A.</first_name>\n        <party>D</party>\n        <state>NJ</state>\n    ...

# %%
import xml2json

s = '''<?xml version="1.0"?>
<note>
   <to>Tove</to>
   <from>Jani</from>
   <heading>Reminder</heading>
   <body>Don't forget me this weekend!</body>
</note>'''
print xml2json.xml2json(s)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-cf78c953a08a> in <module>()
# ----> 1 import xml2json
#       2
#       3 s = '''<?xml version="1.0"?>
#       4 <note>
#       5    <to>Tove</to>
#
# ImportError: No module named xml2json

# %%
from xmljson import badgerfish as bf
